# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
dataset=pd.read_csv("BigMartSales.csv")
dataset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
dataset.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dataset.shape
# Out:
# (8523, 12)

# %%
dataset['Item_Weight'].fillna(dataset["Item_Weight"].mean(),inplace=True)

# %%
dataset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dataset['Outlet_Size']
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
dataset['Outlet_Size'].mode()[0]
# Out:
# 'Medium'

# %%
dataset["Outlet_Size"].fillna(dataset["Outlet_Size"].mode()[0],inplace=True)

# %%
dataset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dataset.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
dataset.to_csv("Pre_big_mart.csv",index=False)

# %%
dataset.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
dataset.drop(["Item_Identifier","Outlet_Identifier"],axis=1)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
Quan=[]
Qual=[]
for columnName in dataset.columns:
    #print(columnName)
    if(dataset[columnName].dtype=='O'):
        #print("Qual")
        Qual.append(columnName)
    else:
        #print("Quan")
        Quan.append(columnName)

# %%
Quan
# Out:
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Outlet_Sales']

# %%
Qual
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
dataset.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%",
                               "IQR",'1.5rule',"lesser","greater","min","max","kurtosis","skew","var","std"],columns=Quan)
for columnName in Quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-  descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()
    descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
    descriptive[columnName]["skew"]=dataset[columnName].skew()
    descriptive[columnName]["var"]=dataset[columnName].var()
    descriptive[columnName]["std"]=dataset[columnName].std()

# %%
descriptive
# Out:
#          Item_Weight Item_Visibility     Item_MRP Outlet_Establishment_Year  \
# mean       12.857645        0.066132   140.992782               1997.831867
# median     12.857645        0.053931     143.0128                    1999.0
# mode       12.857645             0.0     172.0422                      1985
# Q1:25%          9.31        0.026989      93.8265                    1987.0
# Q2:50%     12.857645        0.053931     143.0128                    1999.0
# Q3:75%          16.0        0.094585     185.6437                    2004.0
# Q4:100%        21.35        0.328391     266.8884                    2009.0
# IQR             6.69        0.067596      91.8172                      17.0
# 1.5rule       10.035        0.101394     137.7258                      25.5
# lesser        -0.725       -0.074404     -43.8993                    1961.5
# greater       26.035        0.195979     323.3695                    2029.5
# ...

# %%
def freqTable(columnName,dataset):
    freqTable=pd.DataFrame(columns=["unique_values","frequency","relative frequency","cumsum"])
    freqTable["unique_values"]=dataset[columnName].value_counts().index
    freqTable["frequency"]=dataset[columnName].value_counts().values
    freqTable["relative frequency"]=(freqTable["frequency"]/103)
    freqTable["cumsum"]=freqTable["relative frequency"].cumsum()
    return freqTable

# %%
freqTable(columnName,dataset)
# Out:
#       unique_values  frequency  relative frequency     cumsum
# 0          958.7520         17            0.165049   0.165049
# 1         1342.2528         16            0.155340   0.320388
# 2          703.0848         15            0.145631   0.466019
# 3         1845.5976         15            0.145631   0.611650
# 4         1278.3360         14            0.135922   0.747573
# ...             ...        ...                 ...        ...
# 3488      4124.6310          1            0.009709  82.708738
# 3489      6622.7126          1            0.009709  82.718447
# 3490      1614.5650          1            0.009709  82.728155
# 3491      5602.7070          1            0.009709  82.737864
# 3492      2778.3834          1            0.009709  82.747573
#
# [3493 rows x 4 columns]

# %%
 dataset.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
sns.distplot(dataset["Item_Weight"],hist=True,kde_kws={'color':'red'})
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
sns.distplot(dataset["Item_Visibility"],hist=True,kde_kws={'color':'green'})
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
sns.distplot(dataset["Item_MRP"],hist=True,kde_kws={'color':'green'})
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
sns.distplot(dataset["Outlet_Establishment_Year"],hist=True,kde_kws={'color':'green'})
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
sns.distplot(dataset["Item_Outlet_Sales"],hist=True,kde_kws={'color':'green'})
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
sns.pairplot(dataset)

# %%
sns.jointplot(x='Item_MRP',y='Item_Type',data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.jointplot(x='Item_Outlet_Sales',y='Outlet_Type',data=dataset)
plt.show()

# %%
sns.jointplot(x='Item_MRP',y='Item_Outlet_Sales',data=dataset,kind='hex')
plt.show()

# %%
sns.pairplot(dataset,hue='Item_Type',diag_kind='kde',kind="scatter",palette='husl')
plt.show()

# %%
sns.stripplot(x='Outlet_Size',y='Item_Type',data=dataset,jitter=True)
plt.show()

# %%
sns.stripplot(x='Outlet_Location_Type',y='Outlet_Type',data=dataset,jitter=True)
plt.show()

# %%
sns.violinplot(x='Outlet_Type',y='Item_Outlet_Sales',data=dataset,jitter=True)
plt.show()

# %%
sns.boxplot(x='Outlet_Size',y='Item_Weight',data=dataset)
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()
dataset['Item_Fat_Content']=encoder.fit_transform(dataset['Item_Fat_Content'])
dataset['Outlet_Size']=encoder.fit_transform(dataset['Outlet_Size'])
dataset['Outlet_Location_Type']=encoder.fit_transform(dataset['Outlet_Location_Type'])
dataset['Outlet_Type']=encoder.fit_transform(dataset['Outlet_Type'])

# %%
dataset
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 3              FDX07       19.200                 2         0.000000
# 4              NCD19        8.930                 1         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 1         0.056783
# 8519           FDS36        8.380                 2         0.046982
# 8520           NCJ29       10.600                 1         0.035186
# 8521           FDN46        7.210                 2         0.145221
# 8522           DRG01       14.800                 1         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dataset=pd.get_dummies(dataset,columns=['Item_Type'])

# %%
dataset
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 3              FDX07       19.200                 2         0.000000
# 4              NCD19        8.930                 1         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 1         0.056783
# 8519           FDS36        8.380                 2         0.046982
# 8520           NCJ29       10.600                 1         0.035186
# 8521           FDN46        7.210                 2         0.145221
# 8522           DRG01       14.800                 1         0.044878
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
dataset.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
dataset
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 1         0.016047  249.8092
# 1           5.920                 2         0.019278   48.2692
# 2          17.500                 1         0.016760  141.6180
# 3          19.200                 2         0.000000  182.0950
# 4           8.930                 1         0.000000   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 1         0.056783  214.5218
# 8519        8.380                 2         0.046982  108.1570
# 8520       10.600                 1         0.035186   85.1224
# 8521        7.210                 2         0.145221  103.1332
# 8522       14.800                 1         0.044878   75.4670
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                          1999            1                     0
# 1                          2009            1                     2
# ...

# %%
dataset.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Item_Type_Baking Goods',
#        'Item_Type_Breads', 'Item_Type_Breakfast', 'Item_Type_Canned',
#        'Item_Type_Dairy', 'Item_Type_Frozen Foods',
#        'Item_Type_Fruits and Vegetables', 'Item_Type_Hard Drinks',
#        'Item_Type_Health and Hygiene', 'Item_Type_Household', 'Item_Type_Meat',
#        'Item_Type_Others', 'Item_Type_Seafood', 'Item_Type_Snack Foods',
#        'Item_Type_Soft Drinks', 'Item_Type_Starchy Foods'],
#       dtype='object')

# %%
independent=dataset[['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Item_Type_Baking Goods','Item_Type_Breads', 'Item_Type_Breakfast', 'Item_Type_Canned','Item_Type_Dairy', 'Item_Type_Frozen Foods', 'Item_Type_Fruits and Vegetables', 'Item_Type_Hard Drinks','Item_Type_Health and Hygiene', 'Item_Type_Household', 'Item_Type_Meat','Item_Type_Others', 'Item_Type_Seafood', 'Item_Type_Snack Foods','Item_Type_Soft Drinks', 'Item_Type_Starchy Foods']]
dependent=dataset[['Item_Outlet_Sales']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
x_train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 88       6.305000                 2         0.123116   95.6436
# 6813     5.980000                 1         0.043809  146.8418
# 4046    12.857645                 1         0.072317  160.7920
# 8194    12.857645                 2         0.299098  157.8630
# 8293     9.100000                 1         0.080278   47.2718
# ...           ...               ...              ...       ...
# 4373    15.200000                 1         0.020280   49.1034
# 7891    12.857645                 2         0.025616  188.1872
# 4859    13.500000                 2         0.000000   78.3960
# 3264    18.700000                 1         0.104890  121.4072
# 2732    14.000000                 1         0.041355  182.0634
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 88                         1997            2                     0
# 6813                       2007            1                     1
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# array([[-1.07557961e+01,  1.31775540e+01, -7.51298252e+01,
#          9.61207050e+02,  1.98189302e+01, -2.07913965e+02,
#         -3.46837807e+02,  7.79651176e+02,  1.55339680e+15,
#          1.01291487e+15,  6.79438553e+14,  1.62006834e+15,
#          1.62637023e+15,  1.81579126e+15,  2.12146612e+15,
#          9.23849850e+14,  1.46641922e+15,  1.87176439e+15,
#          1.31339769e+15,  8.24116540e+14,  5.09200874e+14,
#          2.10921108e+15,  1.29873378e+15,  7.80335047e+14]])

# %%
bias=regressor.intercept_
bias
# Out:
# array([2167.7180375])

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.5056287964018916

# %%
from sklearn.svm import SVR
regressor=SVR(kernel="linear",C=0.1)
regressor=regressor.fit(x_train,y_train)
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred=regressor.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.15793028161036693

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(criterion="squared_error", splitter="best")
regressor=regressor.fit(x_train,y_train)

# %%
y_pred=regressor.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.17138541329574108

# %%
from sklearn.ensemble import RandomForestRegressor
regressor= RandomForestRegressor(n_estimators = 100, criterion="squared_error")       
regressor=regressor.fit(x_train,y_train)
# Out:
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
y_pred=regressor.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.5522232881074639

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','linear'],
              'C':[10,100,1000],'gamma':['auto']} 
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=1) 
   
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.210 total time=   4.7s
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.202 total time=   4.7s
# ...

# %%
re=grid.cv_results_

grid_predictions = grid.predict(x_test) 
   

from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}: 0.5711839937806653

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       3.119828      0.029280         1.634366        0.028983      10
# 1       2.318771      0.015938         0.312483        0.000012      10
# 2       3.034389      0.022949         1.624979        0.000009     100
# 3       2.790637      0.077553         0.321863        0.012511     100
# 4       3.642565      0.381433         1.690604        0.068046    1000
# 5       6.878895      0.650440         0.306226        0.007655    1000
#
#   param_gamma param_kernel                                            params  \
# 0        auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 1        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 2        auto          rbf      {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 3        auto       linear   {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}
# 4        auto          rbf     {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['mse','mae'],
              'max_features': ['auto','sqrt'],
              'splitter':['best']} 



grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=1) 
   

grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END criterion=mse, max_features=auto, splitter=best;, score=0.142 total time=   0.1s
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\sklearn\tree\_classes.py:363: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\sklearn\tree\_classes.py:363: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# [CV 2/5] END criterion=mse, max_features=auto, splitter=best;, score=0.170 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=best;, score=0.152 total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=best;, score=0.200 total time=   0.0s
# ...

# %%
re=grid.cv_results_

grid_predictions = grid.predict(x_test) 
   

from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'mae', 'max_features': 'sqrt', 'splitter': 'best'}: 0.22057298588774465

# %%
import xgboost as xgb
regressor=xgb.XGBRegressor()
regressor.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
y_pred=regressor.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.5325934129420047

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','firedman_mse'],
              'max_features': ['auto','sqrt'],
              'n_estimators':[10,100]} 



grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=1) 
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\sklearn\model_selection\_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 1/5] END criterion=squared_error, max_features=auto, n_estimators=10;, score=0.529 total time=   0.5s
# D:\ANACONDA\ANA\envs\aiworks\lib\site-packages\sklearn\model_selection\_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 2/5] END criterion=squared_error, max_features=auto, n_estimators=10;, score=0.530 total time=   0.5s
# ...

# %%
 
re=grid.cv_results_

grid_predictions = grid.predict(x_test) 
   

from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.5655550023054688

# %%
import joblib

# %%
joblib.dump(grid,r'E:\2.project\Model\grid.sav')
# Out:
# ['E:\\2.project\\Model\\grid.sav']

# %%
model=joblib.load(r'E:\2.project\Model\grid.sav')

# %%
import pickle
filename="Final_big_mart_model.sav"

# %%
joblib.dump(regressor,r'E:\2.project\Model\rf.sav')
# Out:
# ['E:\\2.project\\Model\\rf.sav']

# %%
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("Final_big_mart_model.sav",'rb'))
